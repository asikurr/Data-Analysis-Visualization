# %%
import pandas as pd

# %%
us_baby = pd.read_csv("us_baby_names.csv")

# %%
us_baby
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# ...          ...        ...   ...    ...    ...
# 1825428  1825429     Zykeem  2014      M      5
# 1825429  1825430     Zymeer  2014      M      5
# 1825430  1825431    Zymiere  2014      M      5
# 1825431  1825432      Zyran  2014      M      5
# 1825432  1825433      Zyrin  2014      M      5
#
# [1825433 rows x 5 columns]

# %%
us_baby['Name']
# Out:
# 0               Mary
# 1               Anna
# 2               Emma
# 3          Elizabeth
# 4             Minnie
#              ...
# 1825428       Zykeem
# 1825429       Zymeer
# 1825430      Zymiere
# 1825431        Zyran
# 1825432        Zyrin
# Name: Name, Length: 1825433, dtype: object

# %%
us_baby_2014 = us_baby.loc[us_baby['Year']==2014, :]

# %%
us_baby_2014
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1792391  1792392    Sophia  2014      F  18490
# 1792392  1792393  Isabella  2014      F  16950
# 1792393  1792394       Ava  2014      F  15586
# ...          ...       ...   ...    ...    ...
# 1825428  1825429    Zykeem  2014      M      5
# 1825429  1825430    Zymeer  2014      M      5
# 1825430  1825431   Zymiere  2014      M      5
# 1825431  1825432     Zyran  2014      M      5
# 1825432  1825433     Zyrin  2014      M      5
#
# [33044 rows x 5 columns]

# %%
us_baby_2014_sort = us_baby_2014.sort_values('Count', ascending = False)

# %%
us_baby_2014_sort.head(10)
# Out:
#               Id      Name  Year Gender  Count
# 1792389  1792390      Emma  2014      F  20799
# 1792390  1792391    Olivia  2014      F  19674
# 1811456  1811457      Noah  2014      M  19144
# 1792391  1792392    Sophia  2014      F  18490
# 1811457  1811458      Liam  2014      M  18342
# 1811458  1811459     Mason  2014      M  17092
# 1792392  1792393  Isabella  2014      F  16950
# 1811459  1811460     Jacob  2014      M  16712
# 1811460  1811461   William  2014      M  16687
# 1811461  1811462     Ethan  2014      M  15619

# %%
us_baby_2014_sort.iloc[5:50]
# Out:
#               Id         Name  Year Gender  Count
# 1811458  1811459        Mason  2014      M  17092
# 1792392  1792393     Isabella  2014      F  16950
# 1811459  1811460        Jacob  2014      M  16712
# 1811460  1811461      William  2014      M  16687
# 1811461  1811462        Ethan  2014      M  15619
# 1792393  1792394          Ava  2014      F  15586
# 1811462  1811463      Michael  2014      M  15323
# 1811463  1811464    Alexander  2014      M  15293
# 1811464  1811465        James  2014      M  14301
# 1811465  1811466       Daniel  2014      M  13829
# 1811466  1811467       Elijah  2014      M  13694
# 1811467  1811468     Benjamin  2014      M  13687
# 1811468  1811469        Logan  2014      M  13579
# 1792394  1792395          Mia  2014      F  13442
# 1811469  1811470        Aiden  2014      M  13296
# 1811470  1811471       Jayden  2014      M  12878
# 1811471  1811472      Matthew  2014      M  12809
# 1792395  1792396        Emily  2014      F  12562
# ...
